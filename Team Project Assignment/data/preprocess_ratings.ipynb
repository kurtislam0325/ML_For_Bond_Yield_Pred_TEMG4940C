# %%
import numpy as np
import pandas as pd
from dateutil.relativedelta import relativedelta

# %%
# @title Mount Google Drive
from google.colab import drive # Load data from google drive
drive.mount("/content/drive")

# %cd "/content/drive/My Drive/Colab_Notebooks/TEAM3_TEMG4940C/data"
# %ls -f
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Colab_Notebooks/TEAM3_TEMG4940C/data
# 1_cleaned_bonds_data.csv   9_stock_price_month.csv
# 2_final_company_info.csv   preprocess_stock_price.ipynb
# 5_matched_stock_prices/    7_credit_spread.csv
# 8_income_stmt/             preprocess_credit_spread.ipynb
# 6_bond_prices/             8_marco_econ_metrics_month.csv
# 9_balance_sheet/           preprocess_financials.ipynb
# 7_cash_flow/               5_financials.csv
# company_financial_ratios/  1_cleaned_bonds_data.gsheet
# 6_marco_econ_metrics.csv   preprocess_ratings.ipynb
# Credit_spread.csv          3_Issue_Ratings.csv
# cleaned_stock_price/       4_Issuer_Ratings.csv

# %%
Bonds_Ratings = pd.read_csv("3_Issue_Ratings.csv")
Issuer_Ratings = pd.read_csv("4_Issuer_Ratings.csv")

# %%
Issuer_Ratings.info()
Bonds_Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88078 entries, 0 to 88077
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Instrument  88078 non-null  int64
#  1   RatingRank  88078 non-null  float64
#  2   Month       88078 non-null  int64
#  3   Year        88078 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 2.7 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43097 entries, 0 to 43096
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ISIN         43097 non-null  object
#  1   Rating Rank  43097 non-null  float64
#  2   Month        43097 non-null  int64
#  3   Year         43097 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.3+ MB

# %%
Bonds_Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43097 entries, 0 to 43096
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ISIN         43097 non-null  object
#  1   Rating Rank  43097 non-null  float64
#  2   Month        43097 non-null  int64
#  3   Year         43097 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.3+ MB

# %%
# def fill_missing_months(df):
#   identifier = df.columns[0]

#   filled = pd.DataFrame()
#   for name, group in df.groupby(identifier):
#     # Get start and end dates
#     start = group['Date'].min()
#     end = group['Date'].max()
#     dates = group['Date'].unique()
#     # Generate list of all monthly dates
#     possible_dates = pd.date_range(start, end, freq='MS')

#     # Loop through years
#     for date in possible_dates:
#       # Check if year is in dataset
#       if date not in dates:
#         prev_date = (group[group['Date'] < date].max())['Date']
#         new_row = group[(group['Date'] == prev_date)]

#         new_row.loc[new_row.index[-1], 'Date'] = date
#         group = pd.concat([group, new_row], axis = 0)
#         group = group.sort_values(by = [identifier, 'Date'])

#     filled = pd.concat([filled, group], axis = 0)

#   filled['Month'] = filled['Date'].dt.month
#   filled['Year'] = filled['Date'].dt.year
#   filled.drop(['Date'], axis=1, inplace=True)

#   return filled

# filled_Bonds_Ratings = fill_missing_months(Bonds_Ratings)
# Bonds_Ratings = filled_Bonds_Ratings

# %%
# @title Handle Issue_Ratings.file

# Bonds_Ratings['Date'] = pd.to_datetime(Bonds_Ratings['Year'].astype(str) + '-' + Bonds_Ratings['Month'].astype(str) + '-1')

# filled_Bond_Ratings = pd.DataFrame()
# for name, group in Bonds_Ratings.groupby("ISIN"):
#   start = group['Date'].max()
#   end = pd.to_datetime("2023/07/01")
#   possible_dates = pd.date_range(start, end, freq='MS')

#   if (possible_dates.shape[0] <= 1):
#     continue

#   last_month = start - pd.offsets.MonthBegin(1)
#   prev_row = group[group['Date'] == last_month]

#   for date in possible_dates:
#     new_row = prev_row.copy()
#     new_row['Date'] = date
#     group = pd.concat([group, new_row])

#   filled_Bond_Ratings = pd.concat([filled_Bond_Ratings, group.reset_index(drop = True)], axis = 0)
#   print(filled_Bond_Ratings)

# %%
# Bonds_Ratings = filled_Bond_Ratings
# Bonds_Ratings = Bonds_Ratings.reset_index(drop = True).sort_values(by = ['ISIN', 'Date'])
# Bonds_Ratings['Year'] = Bonds_Ratings['Date'].dt.year
# Bonds_Ratings['Month'] = Bonds_Ratings['Date'].dt.month

# %%
# @title Output Preprocessed Test Dataset
Issuer_Ratings = Issuer_Ratings.rename(columns = {"Instrument":"PermID"})
Issuer_Ratings.info()
data_csv = Issuer_Ratings.to_csv(index=False)

with open('/content/drive/My Drive/Colab_Notebooks/TEAM3_TEMG4940C/data/4_Issuer_Ratings.csv', 'w') as f:
  f.write(data_csv)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88078 entries, 0 to 88077
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PermID      88078 non-null  int64
#  1   RatingRank  88078 non-null  float64
#  2   Month       88078 non-null  int64
#  3   Year        88078 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 2.7 MB

# %%
# @title Output Preprocessed Test Dataset
Bonds_Ratings = Bonds_Ratings.rename(columns = {"Instrument":"ISIN"}).drop("Date", axis = 1)
data_csv = Bonds_Ratings.to_csv(index=False)

with open('/content/drive/My Drive/Colab_Notebooks/TEAM3_TEMG4940C/data/3_Issue_Ratings.csv', 'w') as f:
  f.write(data_csv)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-135-8aebaa359b05> in <cell line: 2>()
#       1 # @title Output Preprocessed Test Dataset
# ----> 2 Bonds_Ratings = Bonds_Ratings.rename(columns = {"Instrument":"ISIN"}).drop("Date", axis = 1)
#       3 data_csv = Bonds_Ratings.to_csv(index=False)
#       4
#       5 with open('/content/drive/My Drive/Colab_Notebooks/TEAM3_TEMG4940C/data/3_Issue_Ratings.csv', 'w') as f:
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
